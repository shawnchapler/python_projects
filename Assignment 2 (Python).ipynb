# %% [markdown]
# # Problem 1(a).  Fizz, Buzz, Woof.
#
# Write a program that prints the numbers from 1 to 150, except . . .
#
# * When you get a number that's divisible by 3, print "Fizz" instead.
# * When you get a number that's divisible by 5, print "Buzz" instead.
# * When you get a number that's divisible by 7, print "Woof" instead.
#
# If a number is divisible by several of these values, print the appropriate words in the corresponding order.  For example, for 15 you should print "Fizz Buzz", for 35 you should print "Buzz Woof", and for 105 you should print "Fizz Buzz Woof".

# %%
for i in range (1, 151):
        if i%3==0 and i%5==0 and i%7==0:
            magic_word = "Fizz Buzz Woof"       
            print(magic_word)
        elif i%3==0 and i%5==0:
            magic_word = "Fizz Buzz"
            print(magic_word)
        elif i%3==0 and i%7==0:
            magic_word = "Fizz Woof"
            print(magic_word)
        elif i%5==0 and i%7==0:
            magic_word = "Buzz Woof"
            print(magic_word)
        elif i%3==0:
            magic_word = "Fizz"
            print(magic_word)
        elif i%5==0:
            magic_word = "Buzz"
            print(magic_word)
        elif i%7==0:
            magic_word = "Woof"
            print(magic_word)
        else:
            print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# Woof
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# Woof
# Fizz Buzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz Woof
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# Woof
# 29
# Fizz Buzz
# 31
# 32
# Fizz
# 34
# Buzz Woof
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz Woof
# 43
# 44
# Fizz Buzz
# 46
# 47
# Fizz
# Woof
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# Woof
# Fizz
# 58
# 59
# Fizz Buzz
# 61
# 62
# Fizz Woof
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz Woof
# 71
# Fizz
# 73
# 74
# Fizz Buzz
# 76
# Woof
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz Woof
# Buzz
# 86
# Fizz
# 88
# 89
# Fizz Buzz
# Woof
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# Woof
# Fizz
# Buzz
# 101
# Fizz
# 103
# 104
# Fizz Buzz Woof
# 106
# 107
# Fizz
# 109
# Buzz
# Fizz
# Woof
# 113
# Fizz
# Buzz
# 116
# Fizz
# 118
# Woof
# Fizz Buzz
# 121
# 122
# Fizz
# 124
# Buzz
# Fizz Woof
# 127
# 128
# Fizz
# Buzz
# 131
# Fizz
# Woof
# 134
# Fizz Buzz
# 136
# 137
# Fizz
# 139
# Buzz Woof
# Fizz
# 142
# 143
# Fizz
# Buzz
# 146
# ...

# %% [markdown]
# # Problem 1(b) [Optional].  Direction of Play.
#
# Fizz, Buzz, Woof originates as a children's game.  The children sit in a circle.  Initially, play moves clockwise, with each child saying a number in turn.  After "Fizz", play switches direction, and after "Buzz", play switches direction again.  The direction of play continues to switch each time an *odd* number of non-integer words is spoken.  However, two-word substitutions, such as "Fizz Buzz", do *not* change direction of play, but three-word substitutions *do* change the direction of play.
#
# Modify your program from 1(a) so that it indicates the direction of play.  For example, your output should begin:
#
# ```
# Clockwise!
# 1
# 2
# Fizz
# Counterclockwise!
# 4
# Buzz
# Clockwise!
# Fizz
# Counterclockwise!
# Woof
# Clockwise!
# 8
# Fizz
# Counterclockwise!
# Buzz
# Clockwise!
# 11
# Fizz
# Counterclockwise!
# 13
# Woof
# Clockwise!
# Fizz Buzz
# 16
# ```

# %%
for i in range (1, 17):
    direction_a = "Clockwise!"
    direction_b = "Counterclockwise!"       
      
    if i%3==0 and i%5==0 and i%7==0:
            magic_word = "Fizz Buzz Woof"       
            print(magic_word)
            print(direction_a)
    elif i%3==0 and i%5==0:
            magic_word = "Fizz Buzz"
            print(magic_word)
    elif i%3==0 and i%7==0:
            magic_word = "Fizz Woof"
            print(magic_word)
    elif i%5==0 and i%7==0:
            magic_word = "Buzz Woof"
            print(magic_word)
    elif i%3==0:
            magic_word = "Fizz"
            print(magic_word)
            print(direction_b)
    elif i%5==0:
            magic_word = "Buzz"
            print(magic_word)
            print(direction_a)
    elif i%7==0:
            magic_word = "Woof"
            print(magic_word)
            print(direction_a)
    elif i%2 == 0: #even number
            print(i)
    else:
            print(direction_a)
            print(i)
# Out:
# Clockwise!
# 1
# 2
# Fizz
# Counterclockwise!
# 4
# Buzz
# Clockwise!
# Fizz
# Counterclockwise!
# Woof
# Clockwise!
# 8
# Fizz
# Counterclockwise!
# Buzz
# Clockwise!
# Clockwise!
# 11
# Fizz
# Counterclockwise!
# Clockwise!
# 13
# Woof
# Clockwise!
# Fizz Buzz
# 16

# %% [markdown]
# # Problem 2(a).  Mortgage Calculator.
#
# Buying a house is one of the biggest financial transactions that many people ever undertake.  Even a small difference in interest rates or monthly payments can make a large difference in how much you ultimately pay for your mortgage.  However, these details are often buried in masses of paperwork--so it pays to be able to calculate the long-term cost of a mortgage yourself.
#
# In this problem, you will create a mortgage calculator that takes as input the *principal loan amount*, *interest rate*, and *monthly payment*.  As output, your calculator should generate an *amortization table*, and compute how many *years and months* it took to pay off the mortgage, and report the *total amount of payments* over that time.
#
# In a mortgage, the bank lends you a certain amount of principal to purchase a house at a certain interest rate.  Every month, the amount you owe (the balance) first increases due to interest:  1/12 of the interest rate times the current balance.  Then the balance decreases due to your monthly payment.
# For example, suppose you borrow $\$100,000$ at $5\%$ annual interest, with $\$500$ monthly payments.  In the first month, the interest increases the balance by $\$416.67$, and then your payment reduces it by $\$500$, for a remaining balance of $\$99,916.67$.  In the second month, the interest charge is $\$416.32$, and the remaining balance is
# $\$99,832.99$.
# If you continue this process, you get an amortization table like this:
#
# ```
# month	 payment	 interest	 balance
# 1 	     500 		 416.67 	 99916.67
# 2 	     500 		 416.32 	 99832.99
# 3 	     500 		 415.97 	 99748.96
# 4 	     500 		 415.62 	 99664.58
# 5 	     500 		 415.27 	 99579.85
# 6 	     500 		 414.92 	 99494.76
# 7 	     500 		 414.56 	 99409.32
# 8 	     500 		 414.21 	 99323.53
# 9 	     500 		 413.85 	 99237.38
# 10 	    500 		 413.49 	 99150.87
#
# ```
#
# You can also compute the total amount of time and money to pay off the mortgage.  In this example, it takes 35 years and 11 months, and the total amount paid is approximately $\$215,458.84$.
#
# Here are some things to consider when implementing the calculator:
# 1.  For dollar values, only display two digits of precision after the decimal point.  (You can assume that the bank will not round internally!)
# 2.  The final payment will almost certainly be smaller than the others, so be careful to check for that case so you don't end up with a negative balance.
# 3.  If the monthly payment is too small, the balance will go up every month!  If this happens, the program should stop and display an appropriate error message.
# 4.  If you accidentally create an infinite loop, try to interrupt or restart the kernel.
# 5.  Use the modulus or $\%$  operator to separate the years and months.
# 6.  Your program should only display the columns requested, and the rows should be formatted to appear under the appropriate heading.

# %%
#Variables Entered by User.  Converted to float)
principal_loan_amount=input('Enter Loan Amount:  $')
principal_loan_amount=float(principal_loan_amount)

interest_rate=input('Enter Annual Interest Rate: %')
interest_rate=float(interest_rate)

monthly_payment=input('Enter Monthly Payment:  $')
payment=float(monthly_payment)

#convert interest rate into monthly rate
periodic_interest_rate = interest_rate/100/12

#Calculate beginning balance and initialize starting variables for non-user inputs
month = 0
balance = principal_loan_amount
balance_interest = principal_loan_amount*periodic_interest_rate
interest = periodic_interest_rate
total_paid = 0

#Confirm payment is greater than the interest 
if payment < balance_interest:
    print("Payment amount will not cover interest.  Pick a larger payment amount.")

#Print Headers
else:
    print ("Month","\t","Payment","\t", "Interest", "\t", "Balance")

#Calculate amoritization table
    while (payment <= balance):
        month = month + 1
        monthly_principal = float(payment - (balance*periodic_interest_rate))
        bal_interest = float(balance*periodic_interest_rate)
        balance = float(balance - monthly_principal)
        total_paid = total_paid + payment
#format variables for display
        payment_f= "{:8.2f}".format(payment)
        bal_interest_f = "{:8.2f}".format(bal_interest)
        monthly_principal_f = "{:8.2f}".format(monthly_principal)
        balance_f = "{:8.2f}".format(balance)
        print (month,"\t", payment_f, "\t", bal_interest_f, "\t", balance_f)
    else:
        month=month + 1
        payment = float(balance + (balance * periodic_interest_rate))
        monthly_principal = payment - (balance*periodic_interest_rate)
        bal_interest = payment - monthly_principal
        balance = 0
        total_paid = total_paid + payment
        #format variables for display
        payment_f = "{:8.2f}".format(payment)
        bal_interest_f = "{:8.2f}".format(bal_interest)
        monthly_principal_f = "{:8.2f}".format(monthly_principal)
        balance_f = "{:8.2f}".format(balance)
        total_paid_f = "${:,.2f}".format(total_paid)
        month_to_years= int(month/12)
        remain_months = month % 12
    
    
    print (month,"\t", payment_f, "\t", bal_interest_f, "\t", balance_f, "\n")
    print ("Total time to payoff is",month_to_years,"years", remain_months, "months.")
    print ("Total paid is", total_paid_f,".")
# Out:
# Enter Loan Amount:  $100000
# Enter Annual Interest Rate: %5
# Enter Monthly Payment:  $500
# Month 	 Payment 	 Interest 	 Balance
# 1 	   500.00 	   416.67 	 99916.67
# 2 	   500.00 	   416.32 	 99832.99
# 3 	   500.00 	   415.97 	 99748.96
# 4 	   500.00 	   415.62 	 99664.58
# 5 	   500.00 	   415.27 	 99579.85
# 6 	   500.00 	   414.92 	 99494.76
# 7 	   500.00 	   414.56 	 99409.32
# 8 	   500.00 	   414.21 	 99323.53
# 9 	   500.00 	   413.85 	 99237.38
# 10 	   500.00 	   413.49 	 99150.87
# 11 	   500.00 	   413.13 	 99064.00
# 12 	   500.00 	   412.77 	 98976.76
# 13 	   500.00 	   412.40 	 98889.17
# 14 	   500.00 	   412.04 	 98801.20
# 15 	   500.00 	   411.67 	 98712.88
# 16 	   500.00 	   411.30 	 98624.18
# 17 	   500.00 	   410.93 	 98535.11
# 18 	   500.00 	   410.56 	 98445.68
# 19 	   500.00 	   410.19 	 98355.87
# 20 	   500.00 	   409.82 	 98265.68
# 21 	   500.00 	   409.44 	 98175.12
# 22 	   500.00 	   409.06 	 98084.19
# 23 	   500.00 	   408.68 	 97992.87
# ...

# %% [markdown]
# # Problem 2(b). Test Suite.
#
# When writing complicated code, it is always a good idea to test your code on simple examples.  Use the following test cases to make sure your code matches calculations you can perform by hand. (Of course, if it does not match, please fix your code.)  For each test case, print the results.
#
# For each, use $\$500$ for the principal, and an annual interest rate of $5\%$.
# 1. Monthly Payment: $\$100$
# 2. Monthly Payment: $\$500$
# 3. Monthly Payment: $\$1$

# %% [markdown]
# Enter Loan Amount:  $500
# Enter Annual Interest Rate: %5
# Enter Monthly Payment:  $100
# Month 	 Payment 	 Interest 	 Balance
# 1 	 100.00 	   2.08 	 402.08
# 2 	 100.00 	   1.68 	 303.76
# 3 	 100.00 	   1.27 	 205.02
# 4 	 100.00 	   0.85 	 105.88
# 5 	 100.00 	   0.44 	   6.32
# 6 	   6.35 	   0.03 	   0.00
#
# Total time to payoff is 0 years 6 months.
# Total paid is $506.35 .

# %% [markdown]
# Enter Loan Amount:  $500
# Enter Annual Interest Rate: %5
# Enter Monthly Payment:  $500
# Month 	 Payment 	 Interest 	 Balance
# 1 	   500.00 	     2.08 	     2.08
# 2 	     2.09 	     0.01 	     0.00
#
# Total time to payoff is 0 years 2 months.
# Total paid is $502.09 .

# %% [markdown]
# Enter Loan Amount:  $500
# Enter Annual Interest Rate: %5
# Enter Monthly Payment:  $1
# Payment amount will not cover interest.  Pick a larger payment amount.

# %% [markdown]
# # Problem 2(c). Calculator Analysis.
#
# Answer the following questions in a markdown cell.
#
# 1.  Describe in your own words how the mortgage calculator works.  What are the steps you are computing?  What are you keeping track of in each iteration?
# 2.	If you had a mortgage with a principal of $\$250,000$, an interest rate of $4\%$, and a monthly payment of $\$1000$, how long would it take you to pay it off?  How much would you have paid in total?
#
# In a code cell, print the amortization schedule produced by your code for the situation in 2 above.

# %% [markdown]
# 1.  In the mortgage calculator, I am performing the following steps:
#
#     a. checking the user input variables to ensure the payment amount is greater than the minimum interest payment.
#     b. checking the payment against the beginning balance for the amoritization period and adjusting the calculation of the    payment amount to accommodate the final payment which is less than the regular payments.
#     c. calculating the amoritization period, principal, interest, accumulated payments, and total amoritization periods
#     d. printing the amoritization schedule along with the total payments paid and total amoritization period.

# %%
#Variables Entered by User.  Converted to float)
principal_loan_amount=input('Enter Loan Amount:  $')
principal_loan_amount=float(principal_loan_amount)

interest_rate=input('Enter Annual Interest Rate: %')
interest_rate=float(interest_rate)

monthly_payment=input('Enter Monthly Payment:  $')
payment=float(monthly_payment)

#convert interest rate into monthly rate
periodic_interest_rate = interest_rate/100/12

#Calculate beginning balance and initialize starting variables for non-user inputs
month = 0
balance = principal_loan_amount
balance_interest = principal_loan_amount*periodic_interest_rate
interest = periodic_interest_rate
total_paid = 0



#Confirm payment is greater than the interest 
if payment < balance_interest:
       print ("Payment amount will not cover interest.  Pick a larger payment amount."), 
else:
#Print Headers
    print ("Month","\t","Payment","\t", "Interest", "\t", "Balance")  

#Calculate amoritization table
while (payment <= balance):
    month = month + 1
    monthly_principal = float(payment - (balance*periodic_interest_rate))
    bal_interest = float(balance*periodic_interest_rate)
    balance = float(balance - monthly_principal)
    total_paid = total_paid + payment
#format variables for display
    payment_f= "{:8.2f}".format(payment)
    bal_interest_f = "{:8.2f}".format(bal_interest)
    monthly_principal_f = "{:8.2f}".format(monthly_principal)
    balance_f = "{:8.2f}".format(balance)
    print (month,"\t", payment_f, "\t", bal_interest_f, "\t", balance_f)
else:
    month=month + 1
    payment = float(balance + (balance * periodic_interest_rate))
    monthly_principal = payment - (balance*periodic_interest_rate)
    bal_interest = payment - monthly_principal
    balance = 0
    total_paid = total_paid + payment
    #format variables for display
    payment_f = "{:8.2f}".format(payment)
    bal_interest_f = "{:8.2f}".format(bal_interest)
    monthly_principal_f = "{:8.2f}".format(monthly_principal)
    balance_f = "{:8.2f}".format(balance)
    total_paid_f = "${:,.2f}".format(total_paid)
    month_to_years= int(month/12)
    remain_months = month % 12
    
    
    print (month,"\t", payment_f, "\t", bal_interest_f, "\t", balance_f, "\n")
    print ("Total time to payoff is",month_to_years,"years", remain_months, "months.")
    print ("Total paid is", total_paid_f,".")
# Out:
# Enter Loan Amount:  $250000
# Enter Annual Interest Rate: %4
# Enter Monthly Payment:  $1000
# Month 	 Payment 	 Interest 	 Balance
# 1 	  1000.00 	   833.33 	 249833.33
# 2 	  1000.00 	   832.78 	 249666.11
# 3 	  1000.00 	   832.22 	 249498.33
# 4 	  1000.00 	   831.66 	 249329.99
# 5 	  1000.00 	   831.10 	 249161.09
# 6 	  1000.00 	   830.54 	 248991.63
# 7 	  1000.00 	   829.97 	 248821.60
# 8 	  1000.00 	   829.41 	 248651.01
# 9 	  1000.00 	   828.84 	 248479.84
# 10 	  1000.00 	   828.27 	 248308.11
# 11 	  1000.00 	   827.69 	 248135.80
# 12 	  1000.00 	   827.12 	 247962.92
# 13 	  1000.00 	   826.54 	 247789.47
# 14 	  1000.00 	   825.96 	 247615.43
# 15 	  1000.00 	   825.38 	 247440.82
# 16 	  1000.00 	   824.80 	 247265.62
# 17 	  1000.00 	   824.22 	 247089.84
# 18 	  1000.00 	   823.63 	 246913.47
# 19 	  1000.00 	   823.04 	 246736.51
# 20 	  1000.00 	   822.46 	 246558.97
# 21 	  1000.00 	   821.86 	 246380.83
# 22 	  1000.00 	   821.27 	 246202.10
# ...

# %% [markdown]
# 2.b - Total time to pay is 44 years 11 months.
